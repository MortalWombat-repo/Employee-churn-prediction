# %% [markdown]
# # Employee turnover prediction

# %% [markdown]
# ## Data preparation and data cleaning

# %%
import pandas as pd

# %% [markdown]
# **Importing data**

# %%
df = pd.read_csv("employee_churn_data.csv")
df
# Out:
#       department  promoted    review  projects  salary  tenure  satisfaction  \
# 0     operations         0  0.577569         3     low     5.0      0.626759
# 1     operations         0  0.751900         3  medium     6.0      0.443679
# 2        support         0  0.722548         3  medium     6.0      0.446823
# 3      logistics         0  0.675158         4    high     8.0      0.440139
# 4          sales         0  0.676203         3    high     5.0      0.577607
# ...          ...       ...       ...       ...     ...     ...           ...
# 9535  operations         0  0.610988         4  medium     8.0      0.543641
# 9536   logistics         0  0.746887         3  medium     8.0      0.549048
# 9537  operations         0  0.557980         3     low     7.0      0.705425
# 9538          IT         0  0.584446         4  medium     8.0      0.607287
# 9539     finance         0  0.626373         3     low     7.0      0.706455
#
#       bonus  avg_hrs_month left
# 0         0     180.866070   no
# 1         0     182.708149   no
# 2         0     184.416084   no
# 3         0     188.707545   no
# 4         1     179.821083   no
# ...     ...            ...  ...
# 9535      0     188.155738  yes
# 9536      0     188.176164  yes
# 9537      0     186.531008  yes
# 9538      1     187.641370  yes
# 9539      1     185.920934  yes
#
# [9540 rows x 10 columns]

# %% [markdown]
# **Normalizing data (in this case it appears to not be needed but it is better to do this to alleviate possible problems)**

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')

categorical_columns = list(df.dtypes[df.dtypes == 'object'].index)

for c in categorical_columns:
    df[c] = df[c].str.lower().str.replace(' ', '_')
df
# Out:
#       department  promoted    review  projects  salary  tenure  satisfaction  \
# 0     operations         0  0.577569         3     low     5.0      0.626759
# 1     operations         0  0.751900         3  medium     6.0      0.443679
# 2        support         0  0.722548         3  medium     6.0      0.446823
# 3      logistics         0  0.675158         4    high     8.0      0.440139
# 4          sales         0  0.676203         3    high     5.0      0.577607
# ...          ...       ...       ...       ...     ...     ...           ...
# 9535  operations         0  0.610988         4  medium     8.0      0.543641
# 9536   logistics         0  0.746887         3  medium     8.0      0.549048
# 9537  operations         0  0.557980         3     low     7.0      0.705425
# 9538          it         0  0.584446         4  medium     8.0      0.607287
# 9539     finance         0  0.626373         3     low     7.0      0.706455
#
#       bonus  avg_hrs_month left
# 0         0     180.866070   no
# 1         0     182.708149   no
# 2         0     184.416084   no
# 3         0     188.707545   no
# 4         1     179.821083   no
# ...     ...            ...  ...
# 9535      0     188.155738  yes
# 9536      0     188.176164  yes
# 9537      0     186.531008  yes
# 9538      1     187.641370  yes
# 9539      1     185.920934  yes
#
# [9540 rows x 10 columns]

# %% [markdown]
# **Converting target variable to a numeric value**

# %%
df.left = (df.left == 'yes').astype(int)
df.left.value_counts()
# Out:
# left
# 0    6756
# 1    2784
# Name: count, dtype: int64

# %%
df[['left']]
# Out:
#       left
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ...    ...
# 9535     1
# 9536     1
# 9537     1
# 9538     1
# 9539     1
#
# [9540 rows x 1 columns]

# %% [markdown]
# **Checking for missing values (no missing values found)**

# %%
df.isnull().sum()
# Out:
# department       0
# promoted         0
# review           0
# projects         0
# salary           0
# tenure           0
# satisfaction     0
# bonus            0
# avg_hrs_month    0
# left             0
# dtype: int64

# %% [markdown]
# **Saving the DataFrame**

# %%
df.to_csv('cleaned_employee_churn_data.csv', index=False)

# %%
df = pd.read_csv("cleaned_employee_churn_data.csv")

# %%
df
# Out:
#       department  promoted    review  projects  salary  tenure  satisfaction  \
# 0     operations         0  0.577569         3     low     5.0      0.626759
# 1     operations         0  0.751900         3  medium     6.0      0.443679
# 2        support         0  0.722548         3  medium     6.0      0.446823
# 3      logistics         0  0.675158         4    high     8.0      0.440139
# 4          sales         0  0.676203         3    high     5.0      0.577607
# ...          ...       ...       ...       ...     ...     ...           ...
# 9535  operations         0  0.610988         4  medium     8.0      0.543641
# 9536   logistics         0  0.746887         3  medium     8.0      0.549048
# 9537  operations         0  0.557980         3     low     7.0      0.705425
# 9538          it         0  0.584446         4  medium     8.0      0.607287
# 9539     finance         0  0.626373         3     low     7.0      0.706455
#
#       bonus  avg_hrs_month  left
# 0         0     180.866070     0
# 1         0     182.708149     0
# 2         0     184.416084     0
# 3         0     188.707545     0
# 4         1     179.821083     0
# ...     ...            ...   ...
# 9535      0     188.155738     1
# 9536      0     188.176164     1
# 9537      0     186.531008     1
# 9538      1     187.641370     1
# 9539      1     185.920934     1
#
# [9540 rows x 10 columns]

# %%
df.T
# Out:
#                      0           1           2           3           4     \
# department     operations  operations     support   logistics       sales
# promoted                0           0           0           0           0
# review           0.577569      0.7519    0.722548    0.675158    0.676203
# projects                3           3           3           4           3
# salary                low      medium      medium        high        high
# tenure                5.0         6.0         6.0         8.0         5.0
# satisfaction     0.626759    0.443679    0.446823    0.440139    0.577607
# bonus                   0           0           0           0           1
# avg_hrs_month   180.86607  182.708149  184.416084  188.707545  179.821083
# left                    0           0           0           0           0
#
#                      5           6           7          8         9     ...  \
# department             it       admin     support      sales     sales  ...
# promoted                0           0           0          0         0  ...
# review           0.683206    0.620158    0.499567   0.652818  0.642031  ...
# projects                2           4           4          4         3  ...
# salary             medium        high      medium        low    medium  ...
# tenure                5.0         5.0         7.0        6.0       6.0  ...
# satisfaction     0.565252    0.686951    0.720451   0.678696  0.623365  ...
# bonus                   1           0           1          0         0  ...
# avg_hrs_month  178.841879  181.142956  184.977538  183.65579   181.851  ...
# left                    0           0           0          0         0  ...
#
#                       9530        9531         9532        9533         9534  \
# department     engineering      retail  engineering  operations  engineering
# promoted                 0           0            0           0            0
# review            0.651929    0.771905     0.701959    0.711253     0.639663
# projects                 4           3            4           4            3
# salary                 low        high       medium      medium       medium
# tenure                 7.0         8.0          8.0         8.0          7.0
# satisfaction      0.745873    0.619672     0.645299    0.534439     0.717815
# bonus                    0           0            0           0            0
# avg_hrs_month   187.114221  188.750091   188.448342  189.241601   187.426777
# left                     1           1            1           1            1
#
#                      9535        9536        9537       9538        9539
# department     operations   logistics  operations         it     finance
# promoted                0           0           0          0           0
# review           0.610988    0.746887     0.55798   0.584446    0.626373
# projects                4           3           3          4           3
# salary             medium      medium         low     medium         low
# tenure                8.0         8.0         7.0        8.0         7.0
# satisfaction     0.543641    0.549048    0.705425   0.607287    0.706455
# bonus                   0           0           0          1           1
# avg_hrs_month  188.155738  188.176164  186.531008  187.64137  185.920934
# left                    1           1           1          1           1
#
# [10 rows x 9540 columns]
